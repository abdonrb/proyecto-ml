# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import sys
from scipy.stats import chi2_contingency,chi2,f_oneway,t
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

# %%
sys.path.append(os.path.abspath("..\src"))
from utils.ClaseAbdon import DataFrameAnalyzer

# %%
tienda = pd.read_csv('../data/raw/merch_sales.csv')

# %%
df = tienda.copy()

# %%
df.head()
# Out:
#    Order ID  Order Date Product ID Product Category Buyer Gender  Buyer Age  \
# 0    189440  2024-07-21     BF1543         Clothing         Male         30
# 1    187385  2024-07-20     BF1543         Clothing         Male         32
# 2    181844  2024-07-21     BF1544            Other       Female         26
# 3    197934  2024-08-19     BF1544            Other         Male         28
# 4    122470  2024-01-06     BF1545            Other       Female         19
#
#   Order Location International Shipping  Sales Price  Shipping Charges  \
# 0     New Jersey                     No          100                 0
# 1      Las Vegas                     No          100                 0
# 2        Cardiff                    Yes            9                40
# 3     Pittsburgh                     No            9                 0
# 4          Miami                     No           10                 0
#
#    Sales per Unit  Quantity  Total Sales  Rating  \
# 0             100         1          100       4
# 1             100         1          100       3
# 2              49         1           49       2
# 3               9         2           18       3
# 4              10         3           30       5
#
#                                               Review
# 0   The delivery team handled the product with care.
# 1  Had slight delays but the product was in good ...
# 2                                    Waste of Money.
# 3  Had slight delays but the product was in good ...
# 4    Lack of delivery delays is greatly appreciated.

# %%
df.tail()
# Out:
#       Order ID  Order Date Product ID Product Category Buyer Gender  \
# 7389    136943  2023-12-10     BF1548         Clothing         Male
# 7390    172276  2024-01-24     BF1546         Clothing       Female
# 7391    160191  2023-12-19     BF1552        Ornaments         Male
# 7392    195268  2023-12-07     BF1555            Other         Male
# 7393    138160  2024-10-23     BF1544            Other       Female
#
#       Buyer Age Order Location International Shipping  Sales Price  \
# 7389         23      Las Vegas                     No           65
# 7390         26     Manchester                    Yes          118
# 7391         19          Miami                     No           45
# 7392         34          Miami                     No           23
# 7393         28      Cleveland                     No            9
#
#       Shipping Charges  Sales per Unit  Quantity  Total Sales  Rating  \
# 7389                 0              65         1           65       4
# 7390                40             158         1          158       4
# 7391                 0              45         1           45       2
# 7392                 0              23         1           23       5
# 7393                 0               9         1            9       1
#
#                                                  Review
# 7389  The product was affordable here compared to ot...
# 7390  Exquisite craftsmanship here is absolutely app...
# 7391                                    Waste of Money.
# 7392  The product was affordable here compared to ot...
# 7393            Careless handling by the delivery team.

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Product ID', 'Product Category',
#        'Buyer Gender', 'Buyer Age', 'Order Location', 'International Shipping',
#        'Sales Price', 'Shipping Charges', 'Sales per Unit', 'Quantity',
#        'Total Sales', 'Rating', 'Review'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Order ID                  0
# Order Date                0
# Product ID                0
# Product Category          0
# Buyer Gender              0
# Buyer Age                 0
# Order Location            0
# International Shipping    0
# Sales Price               0
# Shipping Charges          0
# Sales per Unit            0
# Quantity                  0
# Total Sales               0
# Rating                    0
# Review                    0
# dtype: int64

# %%
df.shape
# Out:
# (7394, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7394 entries, 0 to 7393
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Order ID                7394 non-null   int64
#  1   Order Date              7394 non-null   object
#  2   Product ID              7394 non-null   object
#  3   Product Category        7394 non-null   object
#  4   Buyer Gender            7394 non-null   object
#  5   Buyer Age               7394 non-null   int64
#  6   Order Location          7394 non-null   object
#  7   International Shipping  7394 non-null   object
#  8   Sales Price             7394 non-null   int64
#  9   Shipping Charges        7394 non-null   int64
#  10  Sales per Unit          7394 non-null   int64
#  11  Quantity                7394 non-null   int64
#  12  Total Sales             7394 non-null   int64
#  13  Rating                  7394 non-null   int64
#  14  Review                  7394 non-null   object
# dtypes: int64(8), object(7)
# memory usage: 866.6+ KB

# %%
# No tenemos datos duplicados.
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Order ID, Order Date, Product ID, Product Category, Buyer Gender, Buyer Age, Order Location, International Shipping, Sales Price, Shipping Charges, Sales per Unit, Quantity, Total Sales, Rating, Review]
# Index: []

# %%
# Reemplazamos los " " en las variables por "_".
list1 = []
list2 = []
for col in df.columns:
    list1.append(col.replace(' ','_'))
    list2.append(col)
a = dict(zip(list2,list1))
df.rename(columns=a,inplace=True)

# %%
# Transformamos la columna Order Date a DateTime
df['Order_Date'] = pd.to_datetime(df['Order_Date'])

# %%
# Eliminamos la columna Review, no trabajaremos sobre ella.
df.pop('Review')
# Out:
# 0        The delivery team handled the product with care.
# 1       Had slight delays but the product was in good ...
# 2                                         Waste of Money.
# 3       Had slight delays but the product was in good ...
# 4         Lack of delivery delays is greatly appreciated.
#                               ...
# 7389    The product was affordable here compared to ot...
# 7390    Exquisite craftsmanship here is absolutely app...
# 7391                                      Waste of Money.
# 7392    The product was affordable here compared to ot...
# 7393              Careless handling by the delivery team.
# Name: Review, Length: 7394, dtype: object

# %%
# Realizamos una exploracion a los valores unicos de cada columna tipo object.
df_ob = df.select_dtypes('object')
for col in df_ob.columns:
    print(f'==========={col}===========')
    print(f'Numero de unicos: {df[col].nunique()}')
    print(f'Valores Unicos: {df[col].unique()}')
    print('\n')
# Out:
# ===========Product_ID===========
# Numero de unicos: 13
# Valores Unicos: ['BF1543' 'BF1544' 'BF1545' 'BF1546' 'BF1547' 'BF1548' 'BF1549' 'BF1550'
#  'BF1551' 'BF1552' 'BF1553' 'BF1554' 'BF1555']
#
#
# ===========Product_Category===========
# Numero de unicos: 3
# Valores Unicos: ['Clothing' 'Other' 'Ornaments']
#
#
# ===========Buyer_Gender===========
# Numero de unicos: 2
# Valores Unicos: ['Male' 'Female']
#
#
# ===========Order_Location===========
# Numero de unicos: 25
# Valores Unicos: ['New Jersey' 'Las Vegas' 'Cardiff' 'Pittsburgh' 'Miami' 'Sydney'
#  'Memphis' 'New York' 'Montreal' 'Sacramento' 'Paris' 'San Antonio'
#  'Cleveland' 'London' 'Portland' 'Detroit' 'Dublin' 'Glasgow' 'Austin'
#  'Toronto' 'Mumbai' 'San Francisco' 'Manchester' 'Liverpool' 'New Delhi']
#
#
# ===========International_Shipping===========
# Numero de unicos: 2
# Valores Unicos: ['No' 'Yes']

# %% [markdown]
# Los datos estan compuestos por 7394 filas y 14 columnas, sin duplicados y tampoco datos missing. Las variables tienen las siguientes descripciones:
#
# |Variable|Descripcion|
# |----|----|
# |Order_ID|Identificacion de la orden.|
# |Order_Date|Fecha de la orden.|
# |Product_ID|Identificacion del producto adquirido.|
# |Product_Category|Categoria del producto adquirido.|
# |Buyer_Gender|Genero del comprador.|
# |Buyer_Age|Edad del comprador.|
# |Order_Location|Ubicacion del comprador.|
# |International_Shipping|¿La orden requiere envio internacional? YES/NO.|
# |Sales_Price|Precio unico del producto.|
# |Shipping_Charges|Cargos de envio.|
# |Sales_per_Unit|Precio unico si son 2 o mas productos.|
# |Quantity|Cantidad de productos.|
# |Total_Sales|Pago total de la orden.|
# |Rating|Puntuacion del comprador.|

# %%
analizar = DataFrameAnalyzer(df)

# %%
analizar.resumen()
# Out:
#                    Columna    Tipo de Dato  Cardinalidad  % Cardinalidad  \
# 0                 Order_ID           int64          7394          100.00
# 1               Order_Date  datetime64[ns]           366            4.95
# 2               Product_ID          object            13            0.18
# 3         Product_Category          object             3            0.04
# 4             Buyer_Gender          object             2            0.03
# 5                Buyer_Age           int64            18            0.24
# 6           Order_Location          object            25            0.34
# 7   International_Shipping          object             2            0.03
# 8              Sales_Price           int64            13            0.18
# 9         Shipping_Charges           int64             6            0.08
# 10          Sales_per_Unit           int64            62            0.84
# 11                Quantity           int64             5            0.07
# 12             Total_Sales           int64           195            2.64
# 13                  Rating           int64             5            0.07
#
#     Valores Faltantes  % Valores Faltantes           Categoría
# 0                   0                  0.0     Índice Numérico
# 1                   0                  0.0                Otro
# 2                   0                  0.0     Índice Numérico
# 3                   0                  0.0  Categórica Nominal
# 4                   0                  0.0             Binaria
# 5                   0                  0.0   Numérica Discreta
# 6                   0                  0.0  Categórica Nominal
# 7                   0                  0.0             Binaria
# 8                   0                  0.0   Numérica Discreta
# 9                   0                  0.0   Numérica Discreta
# 10                  0                  0.0   Numérica Discreta
# 11                  0                  0.0   Numérica Discreta
# 12                  0                  0.0   Numérica Discreta
# 13                  0                  0.0   Numérica Discreta

# %% [markdown]
# Tenemos 2 datos categoricos nominales, 2 binarios, 7 numericos discretos, fecha y indices. No tenemos missing y la cardinalidad en la mayoria de variables es baja.

# %%
analizar.describe_categorical()
# Out:
#                         unique_values most_frequent  frequency  proportion
# Product_ID                         13        BF1548       1497       20.25
# Product_Category                    3      Clothing       3704       50.09
# Buyer_Gender                        2          Male       5188       70.16
# Order_Location                     25    New Jersey        434        5.87
# International_Shipping              2            No       5139       69.50

# %% [markdown]
# Podemos observar que el tipo de producto mas vendido es "CLOTHING", el genero que mas ha comprado es el "MALE" y la ubicacion en la que se han realizado mas ordenes es en New Jersey. Mas adelante analizaremos a profundidad estos resultados.

# %%
analizar.describe_numeric()
# Out:
#                    count        mean  median  mode     std_dev   min   25%  \
# Buyer_Age         7394.0   26.455504    26.0    34    5.208202  18.0  22.0
# Sales_Price       7394.0   55.165404    65.0    65   39.575614   9.0  15.0
# Shipping_Charges  7394.0   14.633487     0.0     0   24.815719   0.0   0.0
# Sales_per_Unit    7394.0   69.798891    65.0    65   46.702326   9.0  20.0
# Quantity          7394.0    1.668109     1.0     1    1.081398   1.0   1.0
# Total_Sales       7394.0  115.832026    90.0    65  118.067960   9.0  40.0
# Rating            7394.0    3.499053     4.0     4    1.389731   1.0   3.0
#
#                    50%    75%     max  skewness  kurtosis
# Buyer_Age         26.0   31.0    35.0  0.010084 -1.214206
# Sales_Price       65.0   97.0   130.0  0.338032 -1.250453
# Shipping_Charges   0.0   40.0   100.0  1.652604  2.051472
# Sales_per_Unit    65.0  100.0   230.0  0.449140 -0.516342
# Quantity           1.0    2.0     5.0  1.577708  1.487874
# Total_Sales       90.0  137.0  1000.0  2.258077  6.602692
# Rating             4.0    5.0     5.0 -0.603098 -0.911546

# %% [markdown]
# Vemos que la edad promedio de los compradores es de 26 años 'casi' igual que la media, esto indica que los datos estan centralizados y con pocos valores en los extremos.
# En el precio de venta vemos que hay una STD elevada, esto se debe ser indicativo a que los precios oscilan entre 9$ y 130$.
# En los cargos por envio vemos que la media es de 14.63$ pero la mediana y la moda son 0$, lo que indica que en la mayoria de pedidos no requieren cargos de envio o el coste es muy bajo.
# El promedio de la cantidad de productos por orden es de 1.66 con una mediana de 1, esto indica que la mayoria de las ordenes son de 1 producto.
# El promedio de ventas totales es de 115.83$ con una mediana de 90$, pero vemos que hay un maximo de 1000$ indicando que hay una pequeña cantidad de ordenes que generan montos elevados.

# %%
df.to_csv('Merch_processed.csv',index=0) # Guardamos DataFrame procesado

# %%
# Test CHI2

contingency_table = pd.crosstab(df['Product_Category'], df['Buyer_Gender'])
chi_2, p, dof, expected = chi2_contingency(contingency_table)
print(f"Chi2: {chi_2},\n p-Value: {p}, \n Valores esperados:\n{expected}")

alpha = 0.05
chi2_critical = chi2.ppf(1 - alpha, dof)
print("Valor crítico:", chi2_critical)
# Out:
# Chi2: 4.006793038685365,
#  p-Value: 0.13487639408345306,
#  Valores esperados:
# [[1105.08845009 2598.91154991]
#  [ 673.07763051 1582.92236949]
#  [ 427.83391939 1006.16608061]]
# Valor crítico: 5.991464547107979

# %% [markdown]
# ## Conclusion Test de chi2 Product_category y Buyer_gender
# Con base en el resultado de la prueba de chi-cuadrado, podemos concluir que no hay una relación significativa entre la categoría de producto y el género del comprador en este conjunto de datos. La diferencia observada entre las categorías es probablemente debida al azar y no a una asociación real entre las variables.

# %%
# ANOVA TOTAL_SALES Y PRODUCT_CATEGORY

categories = [df[df['Product_Category'] == category]['Total_Sales'] for category in df['Product_Category'].unique()]
f_statistic, p_value = f_oneway(*categories)

print(f"F-statistic: {f_statistic}, p-value: {p_value}")
# Out:
# F-statistic: 1120.6621251725408, p-value: 0.0

# %% [markdown]
# ## Conclusion de ANOVA entre Product_Category y Total_Sales
# Con base en los resultados del test de ANOVA , podemos concluir que existe una diferencia significativa entre las medias de Product_category y total_Sales. Esto sugiere que las variables que estamos analizando tienen un efecto diferente en las distintas categorias, y la diferencia no es producto del azar.

# %%
# ANOVA BUYER_GENDER Y TOTAL_SALES

categories = [df[df['Buyer_Gender'] == category]['Total_Sales'] for category in df['Buyer_Gender'].unique()]
f_statistic, p_value = f_oneway(*categories)

print(f"F-statistic: {f_statistic}, p-value: {p_value}")
# Out:
# F-statistic: 0.01710476781088159, p-value: 0.8959487922596888

# %% [markdown]
# ## Conclusion de ANOVA entre Buyer_Gender y Total_Sales
# Con base en estos resultados, no encontramos diferencias significativas entre las medias de las categorías: Product_Category y Buyer_Gender. Es decir, el género del comprador no influye significativamente en la compra por la categoria de los productos.

# %%
anova_result = stats.f_oneway(
    df[df["Product_Category"] == "Clothing"]["Sales_Price"],
    df[df["Product_Category"] == "Ornaments"]["Sales_Price"],
    df[df["Product_Category"] == "Other"]["Sales_Price"]
)

anova_results = {
    "ANOVA (F-Estadístico)": anova_result.statistic,
    "ANOVA (p-valor)": anova_result.pvalue
}

anova_results
# Out:
# {'ANOVA (F-Estadístico)': np.float64(14605.450022041108),
#  'ANOVA (p-valor)': np.float64(0.0)}

# %% [markdown]
# ### Conclusion de Anova entre Product_Category y Sales_Price.
# Dado que el p-valor es menor que 0.05, hay una diferencia estadísticamente significativa en los precios de venta entre las distintas categorías de productos. Esto significa que la categoría del producto influye en el precio de venta.

# %%
local_sales = df[df["International_Shipping"] == "No"]["Sales_Price"]
international_sales = df[df["International_Shipping"] == "Yes"]["Sales_Price"]

shapiro_local = stats.shapiro(local_sales.sample(500, random_state=42) if len(local_sales) > 500 else local_sales)
shapiro_international = stats.shapiro(international_sales.sample(500, random_state=42) if len(international_sales) > 500 else international_sales)

levene_test = stats.levene(local_sales, international_sales)

ttest_result = stats.ttest_ind(local_sales, international_sales, equal_var=levene_test.pvalue > 0.05)

test_results = {
    "Shapiro-Wilk Local (p-valor)": shapiro_local.pvalue,
    "Shapiro-Wilk Internacional (p-valor)": shapiro_international.pvalue,
    "Levene Test (p-valor)": levene_test.pvalue,
    "T-Test (Estadístico)": ttest_result.statistic,
    "T-Test (p-valor)": ttest_result.pvalue
}

pd.DataFrame(test_results,index=[1])
# Out:
#    Shapiro-Wilk Local (p-valor)  Shapiro-Wilk Internacional (p-valor)  \
# 1                  6.891540e-19                          2.668757e-19
#
#    Levene Test (p-valor)  T-Test (Estadístico)  T-Test (p-valor)
# 1               0.648507             -0.047237          0.962326

# %% [markdown]
# ## Conclusiones de los test Shapiro-Wilk, Levene Test, T-Test:
# Podemos observar que en el test de Shapiro-Wilk los resultados son menores a 0.05 por lo que no siguen una distribucion normal. En la prueba t el p-valor es mayor a 0.05, por lo que estadisticamente no hay diferencia significativa entre las ventas de envios locales e internacionales.

# %% [markdown]
# ## Análisis temporal.

# %%
df_grouped = df.groupby(["Order_Date", "Product_Category"]).agg(
    total_sales=("Total_Sales", "sum"),
    total_ordenes=("Order_ID", "count")
).reset_index()

df_grouped["media_gastasdo"] = df_grouped["total_sales"] / df_grouped["total_ordenes"]
df_grouped["media_ordenes"] = df_grouped["total_ordenes"] / df_grouped["Order_Date"].nunique()

df_grouped.head()
# Out:
#   Order_Date Product_Category  total_sales  total_ordenes  media_gastasdo  \
# 0 2023-11-05         Clothing         1454              8      181.750000
# 1 2023-11-05        Ornaments          403              8       50.375000
# 2 2023-11-05            Other           97              3       32.333333
# 3 2023-11-06         Clothing         1574             11      143.090909
# 4 2023-11-06        Ornaments          245              7       35.000000
#
#    media_ordenes
# 0       0.021858
# 1       0.021858
# 2       0.008197
# 3       0.030055
# 4       0.019126

# %%
# Aplicar suavizado con media móvil de 7 días para una mejor visualización
df_grouped["average_spent_smoothed"] = df_grouped.groupby("Product_Category")["media_gastasdo"].transform(lambda x: x.rolling(window=7, min_periods=1).mean())
df_grouped["order_avg_smoothed"] = df_grouped.groupby("Product_Category")["media_ordenes"].transform(lambda x: x.rolling(window=7, min_periods=1).mean())

plt.figure(figsize=(14, 7))
for category in df_grouped["Product_Category"].unique():
    subset = df_grouped[df_grouped["Product_Category"] == category]
    plt.plot(subset["Order_Date"], subset["average_spent_smoothed"], label=category, linewidth=2.5)

plt.xlabel("Fecha", fontsize=12)
plt.ylabel("Dinero Gastado Promedio ($)", fontsize=12)
plt.title("Tendencia del Dinero Gastado Promedio por Categoría", fontsize=14, fontweight="bold")
plt.legend(title="Categoría de Producto", fontsize=12)
plt.xticks(rotation=45)
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

plt.figure(figsize=(14, 7))
for category in df_grouped["Product_Category"].unique():
    subset = df_grouped[df_grouped["Product_Category"] == category]
    plt.plot(subset["Order_Date"], subset["order_avg_smoothed"], label=category, linewidth=2.5)

plt.xlabel("Fecha", fontsize=12)
plt.ylabel("Órdenes Promedio por Día", fontsize=12)
plt.title("Tendencia de Órdenes Promedio por Categoría", fontsize=14, fontweight="bold")
plt.legend(title="Categoría de Producto", fontsize=12)
plt.xticks(rotation=45)
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
time = DataFrameAnalyzer(df_grouped)

# %%
time.describe_categorical()
# Out:
#                   unique_values most_frequent  frequency  proportion
# Product_Category              3      Clothing        366       33.64

# %%
time.describe_numeric()
# Out:
#                  count        mean      median       mode     std_dev  \
# total_sales     1088.0  787.189338  437.500000  18.000000  806.979626
# total_ordenes   1088.0    6.795956    6.000000   5.000000    3.626629
# media_gastasdo  1088.0   96.645575   73.585714   9.000000   68.305445
# media_ordenes   1088.0    0.018568    0.016393   0.013661    0.009909
#
#                      min         25%         50%          75%          max  \
# total_sales     9.000000  187.000000  437.500000  1276.500000  4128.000000
# total_ordenes   1.000000    4.000000    6.000000     9.000000    21.000000
# media_gastasdo  9.000000   42.638889   73.585714   146.208333   350.857143
# media_ordenes   0.002732    0.010929    0.016393     0.024590     0.057377
#
#                 skewness  kurtosis
# total_sales     1.298084  0.970780
# total_ordenes   0.712197  0.405344
# media_gastasdo  0.848905  0.001583
# media_ordenes   0.712197  0.405344

# %% [markdown]
# ## Conclusiones:
# - Se observa que las categorías de productos tienen comportamientos diferenciados en el tiempo, algunas categorías presentan picos de gasto promedio en ciertos períodos , lo que podría estar asociado a promociones, eventos especiales o cambios estacionales en la demanda.
# - La frecuencia de pedidos varía según la categoría, lo que sugiere que ciertos productos tienen una demanda más estable mientras que otros pueden ser más estacionales. Con respecto a ciertas caidas en algunos productos, podría indicar una bajada en el interés o la necesidad de ajustar estrategias de promoción y stock.

# %%
# Analizando si tenemos outliers
analizar.plot_numeric()

# %%
# Tenemos muchos Outliers en Total_sales, miremos a que se deben.
Q1 = df['Total_Sales'].quantile(0.25)
Q3 = df['Total_Sales'].quantile(0.75)
IQR = Q3 - Q1

upper_limit = Q3 + 1.5 * IQR

# Identificar valores fuera del rango IQR
outl = df[df['Total_Sales'] > upper_limit]
no_outl = df[df['Total_Sales'] < upper_limit]

# %%
# Creamos 2 visualizaciones comparativas de ventas por cantidad, no outliers vs outliers

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Grafico 1: OUTLIERS
sns.barplot(ax=axes[0],x='Quantity', y='Total_Sales', data=outl, estimator=sum)
axes[0].set_title('Sales Quantity by Total_Sales (OUTLIERS)')

# Grafico 2: NO OUTLIERS
sns.barplot(ax=axes[1],x='Quantity', y='Total_Sales', data=no_outl, estimator=sum)
axes[1].set_title('Sales Quantity by Total_Sales (NO OUTLIERS)')

plt.tight_layout()
plt.show()

# %%
# Ordenamos para ver las diferencias entre las ventas por el precio de producto.
no_outl_sorted = no_outl.groupby('Sales_Price')['Total_Sales'].sum().sort_values(ascending=False).index
outl_sorted = outl.groupby('Sales_Price')['Total_Sales'].sum().sort_values(ascending=False).index

# %%
# Creamos 2 visualizaciones comparativas de ventas por cantidad, no outliers vs outliers
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Grafico 1: OUTLIERS
sns.barplot(ax=axes[0],x='Sales_Price', y='Total_Sales', data=outl,estimator=sum,order=outl_sorted)
axes[0].set_title('Sales_Price by Total_Sales (OUTLIERS)')

# Grafico 2: NO OUTLIERS
sns.barplot(ax=axes[1],x='Sales_Price', y='Total_Sales', data=no_outl,estimator=sum,order=no_outl_sorted)
axes[1].set_title('Sales_Price by Total_Sales (NO OUTLIERS)')

plt.tight_layout()
plt.show()

# %%
# Test de Grubbs

data = df['Total_Sales']

mean = np.mean(data)
std = np.std(data, ddof=1)
G = max(abs(data - mean)) / std
n = len(data)

# Valor crítico de Grubbs
alpha = 0.05
t_crit = t.ppf(1 - alpha / (2 * n), n - 2)
G_crit = ((n - 1) / np.sqrt(n)) * np.sqrt(t_crit**2 / (n - 2 + t_crit**2))

print(f"Estadístico G: {G}, Valor crítico G: {G_crit}")
# Out:
# Estadístico G: 7.488635980149951, Valor crítico G: 4.498107725353283

# %% [markdown]
# ### Resultado Test de Grubbs:
# - Aunque la prueba señala que existen valores estadisticamente atipicos, el analisis del contexto actual demuestra que estos datos son relevantes para el negocio y deben mantenerse en el Dataset. Esto muestra un enfoque analitico equilibrado entre estadística y contexto.

# %% [markdown]
# ### Conclusion sobre OUTLIERS.
# - Sales_per_unit: Tenemos un outlier no muy alejado del ultimo dato, no lo imputaremos.
# - Quantity: Tenemos 2 outliers que tambien dejaremos debido a que nos parece normal que haya 2 pedidos con mas cantitades de productos
# - Total_sales: Tenemos muchos outliers, pero podemos observar que muchos de ellos son por pedidos de mas de 3 productos, y de precios mas altos. no los imputaremos debido a que es normal que esto suceda.
